# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
temp = []
max_temp = []
humidity = []
wind_speed = []
clouds = []
city_lat = []
city_lon = []
country = []
city_date = []

# Print opening
print("Beginning Data Retrieval")
print("-----------------------------")

# Set up initial values for record and set counts
record_count = 1
set_count = 1

for city in cities:  
    try:
        print(f"Processing Record {record_count} of Set {set_count} | {city.title()}")
        response = requests.get(query_url + city).json()
        
        temp.append(response['main']['temp'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        clouds.append(response['clouds']['all'])
        city_lat.append(response['coord']['lat'])
        city_lon.append(response['coord']['lon'])
        country.append(response['sys']['country'])
        city_date.append(response['dt'])
        
    except KeyError:
        print(f"City not found. Skipping...")

    record_count += 1
    if record_count == 51:
        record_count = 1
        set_count += 1
        
# Print closing
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Takayama
# Processing Record 2 of Set 1 | Bluff
# Processing Record 3 of Set 1 | Puerto Ayora
# Processing Record 4 of Set 1 | Dikson
# Processing Record 5 of Set 1 | Ponta Do Sol
# Processing Record 6 of Set 1 | Tenango De Rio Blanco
# City not found. Skipping...
# Processing Record 7 of Set 1 | Clarksdale
# Processing Record 8 of Set 1 | Hobart
# Processing Record 9 of Set 1 | Atuona
# Processing Record 10 of Set 1 | Vaini
# Processing Record 11 of Set 1 | Ushuaia
# Processing Record 12 of Set 1 | Paamiut
# Processing Record 13 of Set 1 | Olafsvik
# Processing Record 14 of Set 1 | Rikitea
# Processing Record 15 of Set 1 | Puerto Leguizamo
# Processing Record 16 of Set 1 | Tuktoyaktuk
# Processing Record 17 of Set 1 | Cape Town
# Processing Record 18 of Set 1 | Georgetown
# Processing Record 19 of Set 1 | Dalnerechensk
# Processing Record 20 of Set 1 | Aswan
# Processing Record 21 of Set 1 | Adrar
# Processing Record 22 of Set 1 | Marcona
# City not found. Skipping...
# Processing Record 23 of Set 1 | Jasper
# Processing Record 24 of Set 1 | Palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 1 | Hithadhoo
# Processing Record 26 of Set 1 | Saalfelden
# City not found. Skipping...
# Processing Record 27 of Set 1 | Utiroa
# City not found. Skipping...
# Processing Record 28 of Set 1 | Nanortalik
# Processing Record 29 of Set 1 | Longyearbyen
# Processing Record 30 of Set 1 | Hermanus
# Processing Record 31 of Set 1 | Busselton
# Processing Record 32 of Set 1 | Seddon
# Processing Record 33 of Set 1 | Kavieng
# Processing Record 34 of Set 1 | Saint-Philippe
# Processing Record 35 of Set 1 | New Norfolk
# Processing Record 36 of Set 1 | Cidreira
# Processing Record 37 of Set 1 | Katsuura
# Processing Record 38 of Set 1 | East London
# Processing Record 39 of Set 1 | Illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | Coquimbo
# Processing Record 41 of Set 1 | Caceres
# Processing Record 42 of Set 1 | Barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | Suntar
# Processing Record 44 of Set 1 | Bredasdorp
# Processing Record 45 of Set 1 | Stilis
# City not found. Skipping...
# Processing Record 46 of Set 1 | Punta Arenas
# Processing Record 47 of Set 1 | Puerto Baquerizo Moreno
# Processing Record 48 of Set 1 | Mys Shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | Nikolskoye
# Processing Record 50 of Set 1 | San Patricio
# Processing Record 1 of Set 2 | Maputo
# Processing Record 2 of Set 2 | Carnarvon
# Processing Record 3 of Set 2 | Kaeo
# Processing Record 4 of Set 2 | Zlatoustovsk
# City not found. Skipping...
# Processing Record 5 of Set 2 | Port Elizabeth
# Processing Record 6 of Set 2 | Mackay
# Processing Record 7 of Set 2 | Amambai
# Processing Record 8 of Set 2 | Yellowknife
# Processing Record 9 of Set 2 | Serov
# Processing Record 10 of Set 2 | Waipawa
# Processing Record 11 of Set 2 | Aleksandrov Gay
# Processing Record 12 of Set 2 | Toora-Khem
# Processing Record 13 of Set 2 | Airai
# Processing Record 14 of Set 2 | Kyaukse
# Processing Record 15 of Set 2 | Pochutla
# Processing Record 16 of Set 2 | Seymchan
# Processing Record 17 of Set 2 | Rudnichnyy
# Processing Record 18 of Set 2 | Taltal
# Processing Record 19 of Set 2 | Belushya Guba
# City not found. Skipping...
# Processing Record 20 of Set 2 | Saint-Junien
# Processing Record 21 of Set 2 | Bengkulu
# Processing Record 22 of Set 2 | Krasnoselkup
# Processing Record 23 of Set 2 | Kibala
# Processing Record 24 of Set 2 | Phuthaditjhaba
# Processing Record 25 of Set 2 | Mataura
# Processing Record 26 of Set 2 | Skagastrond
# City not found. Skipping...
# Processing Record 27 of Set 2 | Arraial Do Cabo
# Processing Record 28 of Set 2 | Port Moresby
# Processing Record 29 of Set 2 | Thinadhoo
# Processing Record 30 of Set 2 | Coihaique
# Processing Record 31 of Set 2 | Port Alfred
# Processing Record 32 of Set 2 | Ardakan
# Processing Record 33 of Set 2 | Winchester
# Processing Record 34 of Set 2 | Sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | Jutai
# Processing Record 36 of Set 2 | Chardara
# Processing Record 37 of Set 2 | Acarau
# Processing Record 38 of Set 2 | Vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 2 | Castro
# Processing Record 40 of Set 2 | Bethel
# Processing Record 41 of Set 2 | Novyy Urengoy
# Processing Record 42 of Set 2 | Kabin Buri
# Processing Record 43 of Set 2 | Grand River South East
# City not found. Skipping...
# Processing Record 44 of Set 2 | Ilulissat
# Processing Record 45 of Set 2 | Barrow
# Processing Record 46 of Set 2 | Mazatlan
# Processing Record 47 of Set 2 | Tasiilaq
# Processing Record 48 of Set 2 | Wajima
# Processing Record 49 of Set 2 | Stutterheim
# Processing Record 50 of Set 2 | Saskylakh
# Processing Record 1 of Set 3 | Dromolaxia
# Processing Record 2 of Set 3 | Oyem
# Processing Record 3 of Set 3 | Neiafu
# Processing Record 4 of Set 3 | Walvis Bay
# Processing Record 5 of Set 3 | Kamaishi
# Processing Record 6 of Set 3 | Mar Del Plata
# Processing Record 7 of Set 3 | Pisco
# Processing Record 8 of Set 3 | Ust-Maya
# Processing Record 9 of Set 3 | Chapais
# Processing Record 10 of Set 3 | Batsfjord
# Processing Record 11 of Set 3 | Natal
# Processing Record 12 of Set 3 | Cayenne
# Processing Record 13 of Set 3 | Kenai
# Processing Record 14 of Set 3 | Ambovombe
# Processing Record 15 of Set 3 | Carbonia
# Processing Record 16 of Set 3 | Zhigansk
# Processing Record 17 of Set 3 | Aklavik
# Processing Record 18 of Set 3 | Tiksi
# Processing Record 19 of Set 3 | Provideniya
# Processing Record 20 of Set 3 | Jamestown
# Processing Record 21 of Set 3 | Komsomolskiy
# Processing Record 22 of Set 3 | Fairbanks
# Processing Record 23 of Set 3 | Chokurdakh
# Processing Record 24 of Set 3 | Ostrovnoy
# Processing Record 25 of Set 3 | Alofi
# Processing Record 26 of Set 3 | Albany
# Processing Record 27 of Set 3 | Touros
# Processing Record 28 of Set 3 | Egvekinot
# Processing Record 29 of Set 3 | Kurchatov
# Processing Record 30 of Set 3 | Nago
# Processing Record 31 of Set 3 | Acajutla
# Processing Record 32 of Set 3 | Margate
# Processing Record 33 of Set 3 | Alenquer
# Processing Record 34 of Set 3 | Baykit
# Processing Record 35 of Set 3 | Vostok
# Processing Record 36 of Set 3 | Deputatskiy
# Processing Record 37 of Set 3 | Victoria
# Processing Record 38 of Set 3 | Giresun
# Processing Record 39 of Set 3 | Tlyarota
# City not found. Skipping...
# Processing Record 40 of Set 3 | Birin
# Processing Record 41 of Set 3 | Gidam
# Processing Record 42 of Set 3 | Norman Wells
# Processing Record 43 of Set 3 | Pevek
# Processing Record 44 of Set 3 | Labutta
# City not found. Skipping...
# Processing Record 45 of Set 3 | Keti Bandar
# Processing Record 46 of Set 3 | Port-De-Paix
# City not found. Skipping...
# Processing Record 47 of Set 3 | Lorengau
# Processing Record 48 of Set 3 | Qaanaaq
# Processing Record 49 of Set 3 | Marawi
# Processing Record 50 of Set 3 | Hami
# Processing Record 1 of Set 4 | Taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 4 | Hilo
# Processing Record 3 of Set 4 | Ancud
# Processing Record 4 of Set 4 | Macas
# Processing Record 5 of Set 4 | Reftinskiy
# Processing Record 6 of Set 4 | Bereda
# Processing Record 7 of Set 4 | Chuy
# Processing Record 8 of Set 4 | Rovaniemi
# Processing Record 9 of Set 4 | Khatanga
# Processing Record 10 of Set 4 | Nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 4 | Miles City
# Processing Record 12 of Set 4 | Krionerion
# City not found. Skipping...
# Processing Record 13 of Set 4 | Sao Joao Da Barra
# Processing Record 14 of Set 4 | Namibe
# Processing Record 15 of Set 4 | Nioro
# Processing Record 16 of Set 4 | Tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 4 | Avarua
# Processing Record 18 of Set 4 | Vanimo
# Processing Record 19 of Set 4 | Kodiak
# Processing Record 20 of Set 4 | Tolbazy
# Processing Record 21 of Set 4 | Esperance
# Processing Record 22 of Set 4 | Salinopolis
# Processing Record 23 of Set 4 | Bhinmal
# Processing Record 24 of Set 4 | Leningradskiy
# Processing Record 25 of Set 4 | Husavik
# Processing Record 26 of Set 4 | Aqtobe
# Processing Record 27 of Set 4 | Chumikan
# Processing Record 28 of Set 4 | Chicama
# Processing Record 29 of Set 4 | Muzambinho
# Processing Record 30 of Set 4 | Susangerd
# Processing Record 31 of Set 4 | Baruun-Urt
# Processing Record 32 of Set 4 | Anloga
# Processing Record 33 of Set 4 | Waitati
# Processing Record 34 of Set 4 | Ketchikan
# Processing Record 35 of Set 4 | Lebu
# Processing Record 36 of Set 4 | Raudeberg
# Processing Record 37 of Set 4 | Sawtell
# Processing Record 38 of Set 4 | Kidal
# Processing Record 39 of Set 4 | Harlingen
# Processing Record 40 of Set 4 | Bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 4 | Seaham
# Processing Record 42 of Set 4 | Kieta
# Processing Record 43 of Set 4 | Laguna
# Processing Record 44 of Set 4 | Shelburne
# Processing Record 45 of Set 4 | Stornoway
# Processing Record 46 of Set 4 | Mount Isa
# Processing Record 47 of Set 4 | Lensk
# Processing Record 48 of Set 4 | Sao Filipe
# Processing Record 49 of Set 4 | Karratha
# Processing Record 50 of Set 4 | Ondjiva
# Processing Record 1 of Set 5 | Bekovo
# Processing Record 2 of Set 5 | Jibuti
# Processing Record 3 of Set 5 | Ribeira Grande
# Processing Record 4 of Set 5 | Ajdabiya
# Processing Record 5 of Set 5 | Kelamangalam
# Processing Record 6 of Set 5 | Karsava
# Processing Record 7 of Set 5 | Sladkovo
# Processing Record 8 of Set 5 | Zhuozhou
# City not found. Skipping...
# Processing Record 9 of Set 5 | Portsmouth
# Processing Record 10 of Set 5 | Saldanha
# Processing Record 11 of Set 5 | Rio Gallegos
# Processing Record 12 of Set 5 | Bubaque
# Processing Record 13 of Set 5 | Rameswaram
# Processing Record 14 of Set 5 | Tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 5 | Douglas
# Processing Record 16 of Set 5 | Saleaula
# City not found. Skipping...
# Processing Record 17 of Set 5 | Champoton
# Processing Record 18 of Set 5 | Flin Flon
# Processing Record 19 of Set 5 | Kupang
# Processing Record 20 of Set 5 | Belmonte
# Processing Record 21 of Set 5 | Energetik
# Processing Record 22 of Set 5 | Rongcheng
# Processing Record 23 of Set 5 | Kudat
# Processing Record 24 of Set 5 | Kapaa
# Processing Record 25 of Set 5 | Inirida
# Processing Record 26 of Set 5 | Fort Nelson
# Processing Record 27 of Set 5 | Belaya Gora
# Processing Record 28 of Set 5 | Clyde River
# Processing Record 29 of Set 5 | Lavrentiya
# Processing Record 30 of Set 5 | Barawe
# City not found. Skipping...
# Processing Record 31 of Set 5 | Boende
# Processing Record 32 of Set 5 | Port-Gentil
# Processing Record 33 of Set 5 | Half Moon Bay
# Processing Record 34 of Set 5 | Beringovskiy
# Processing Record 35 of Set 5 | Thompson
# Processing Record 36 of Set 5 | Attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 5 | Yining
# Processing Record 38 of Set 5 | Tianpeng
# Processing Record 39 of Set 5 | Haverfordwest
# Processing Record 40 of Set 5 | Pingliang
# Processing Record 41 of Set 5 | Plainview
# Processing Record 42 of Set 5 | Iqaluit
# Processing Record 43 of Set 5 | Sfantu Gheorghe
# Processing Record 44 of Set 5 | West Wendover
# Processing Record 45 of Set 5 | Codrington
# Processing Record 46 of Set 5 | Birao
# Processing Record 47 of Set 5 | Dwarka
# Processing Record 48 of Set 5 | Inveraray
# City not found. Skipping...
# Processing Record 49 of Set 5 | Tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 5 | Velyka Mykhaylivka
# Processing Record 1 of Set 6 | Kutum
# Processing Record 2 of Set 6 | Narsaq
# Processing Record 3 of Set 6 | Bathsheba
# Processing Record 4 of Set 6 | Plouzane
# Processing Record 5 of Set 6 | Sangmelima
# Processing Record 6 of Set 6 | Kaitangata
# Processing Record 7 of Set 6 | Butaritari
# Processing Record 8 of Set 6 | Mayo
# Processing Record 9 of Set 6 | Namatanai
# Processing Record 10 of Set 6 | Springdale
# Processing Record 11 of Set 6 | Geraldton
# Processing Record 12 of Set 6 | Port Hardy
# Processing Record 13 of Set 6 | Paengaroa
# Processing Record 14 of Set 6 | Draguignan
# Processing Record 15 of Set 6 | Ibra
# Processing Record 16 of Set 6 | Upernavik
# Processing Record 17 of Set 6 | Linjiang
# Processing Record 18 of Set 6 | Bukachacha
# Processing Record 19 of Set 6 | Palizada
# Processing Record 20 of Set 6 | Muroto
# Processing Record 21 of Set 6 | Qaqortoq
# Processing Record 22 of Set 6 | Marevo
# Processing Record 23 of Set 6 | Llanes
# Processing Record 24 of Set 6 | Ous
# Processing Record 25 of Set 6 | Amderma
# City not found. Skipping...
# Processing Record 26 of Set 6 | Dalby
# Processing Record 27 of Set 6 | Dustlik
# Processing Record 28 of Set 6 | Saint George
# Processing Record 29 of Set 6 | Ambulu
# Processing Record 30 of Set 6 | Krasnousolskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | Sale
# Processing Record 32 of Set 6 | Floro
# Processing Record 33 of Set 6 | Lukovetskiy
# Processing Record 34 of Set 6 | Cabo San Lucas
# Processing Record 35 of Set 6 | Hobyo
# Processing Record 36 of Set 6 | Huarmey
# Processing Record 37 of Set 6 | Morondava
# Processing Record 38 of Set 6 | Nelson Bay
# Processing Record 39 of Set 6 | Thurso
# Processing Record 40 of Set 6 | Eirunepe
# Processing Record 41 of Set 6 | Kahului
# Processing Record 42 of Set 6 | Torbay
# Processing Record 43 of Set 6 | Kurilsk
# Processing Record 44 of Set 6 | Armacao Dos Buzios
# City not found. Skipping...
# Processing Record 45 of Set 6 | Srednekolymsk
# Processing Record 46 of Set 6 | Ikryanoye
# Processing Record 47 of Set 6 | Brigantine
# Processing Record 48 of Set 6 | Ouesso
# Processing Record 49 of Set 6 | Mahebourg
# Processing Record 50 of Set 6 | Serebryanyy Bor
# Processing Record 1 of Set 7 | Grootfontein
# Processing Record 2 of Set 7 | Luderitz
# Processing Record 3 of Set 7 | Guatire
# Processing Record 4 of Set 7 | Jaipur Hat
# City not found. Skipping...
# Processing Record 5 of Set 7 | Vila Franca Do Campo
# Processing Record 6 of Set 7 | Lake Charles
# Processing Record 7 of Set 7 | Lasa
# Processing Record 8 of Set 7 | Lukuledi
# Processing Record 9 of Set 7 | Makakilo City
# Processing Record 10 of Set 7 | Mehran
# Processing Record 11 of Set 7 | Lasem
# Processing Record 12 of Set 7 | San Jeronimo
# Processing Record 13 of Set 7 | Lumut
# Processing Record 14 of Set 7 | Mana
# Processing Record 15 of Set 7 | Mrirt
# City not found. Skipping...
# Processing Record 16 of Set 7 | Valparaiso
# Processing Record 17 of Set 7 | Ferrol
# Processing Record 18 of Set 7 | Sergeyevka
# Processing Record 19 of Set 7 | San Quintin
# Processing Record 20 of Set 7 | Mulege
# Processing Record 21 of Set 7 | Dingle
# Processing Record 22 of Set 7 | Santarem
# Processing Record 23 of Set 7 | Durusu
# Processing Record 24 of Set 7 | Hasaki
# Processing Record 25 of Set 7 | Tanjong Sepat
# City not found. Skipping...
# Processing Record 26 of Set 7 | Kroya
# Processing Record 27 of Set 7 | Ijaki
# City not found. Skipping...
# Processing Record 28 of Set 7 | Gladstone
# Processing Record 29 of Set 7 | Taoudenni
# Processing Record 30 of Set 7 | Jijiga
# Processing Record 31 of Set 7 | Antalaha
# Processing Record 32 of Set 7 | Guarapari
# Processing Record 33 of Set 7 | Vangaindrano
# Processing Record 34 of Set 7 | Pinawa
# Processing Record 35 of Set 7 | Robertsport
# Processing Record 36 of Set 7 | Fukue
# Processing Record 37 of Set 7 | At-Bashi
# Processing Record 38 of Set 7 | Hrodna
# Processing Record 39 of Set 7 | Maningrida
# Processing Record 40 of Set 7 | Caravelas
# Processing Record 41 of Set 7 | Porangatu
# Processing Record 42 of Set 7 | Bambous Virieux
# Processing Record 43 of Set 7 | Mombetsu
# Processing Record 44 of Set 7 | Gorom-Gorom
# Processing Record 45 of Set 7 | Glens Falls
# Processing Record 46 of Set 7 | Alice Springs
# Processing Record 47 of Set 7 | Toliary
# City not found. Skipping...
# Processing Record 48 of Set 7 | Milkovo
# Processing Record 49 of Set 7 | Biak
# Processing Record 50 of Set 7 | Asau
# Processing Record 1 of Set 8 | Kracheh
# City not found. Skipping...
# Processing Record 2 of Set 8 | Malinovoye Ozero
# Processing Record 3 of Set 8 | Bilibino
# Processing Record 4 of Set 8 | Honningsvag
# Processing Record 5 of Set 8 | Usta Muhammad
# Processing Record 6 of Set 8 | Manta
# Processing Record 7 of Set 8 | Chitral
# Processing Record 8 of Set 8 | Oktyabrskoye
# Processing Record 9 of Set 8 | Binga
# Processing Record 10 of Set 8 | Samusu
# City not found. Skipping...
# Processing Record 11 of Set 8 | Constitucion
# Processing Record 12 of Set 8 | Fort Saint John
# City not found. Skipping...
# Processing Record 13 of Set 8 | Itarema
# Processing Record 14 of Set 8 | Waddan
# Processing Record 15 of Set 8 | Kunmadaras
# Processing Record 16 of Set 8 | Barcelona
# Processing Record 17 of Set 8 | Shimoda
# Processing Record 18 of Set 8 | Kyabe
# Processing Record 19 of Set 8 | Kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 8 | Asayita
# City not found. Skipping...
# Processing Record 21 of Set 8 | Play Cu
# City not found. Skipping...
# Processing Record 22 of Set 8 | Bowen
# Processing Record 23 of Set 8 | Marzuq
# Processing Record 24 of Set 8 | Hirara
# Processing Record 25 of Set 8 | Aksarka
# Processing Record 26 of Set 8 | Maua
# Processing Record 27 of Set 8 | Salalah
# Processing Record 28 of Set 8 | Lolua
# City not found. Skipping...
# Processing Record 29 of Set 8 | Mayahi
# Processing Record 30 of Set 8 | Broome
# Processing Record 31 of Set 8 | Saint-Leu
# Processing Record 32 of Set 8 | Hauterive
# Processing Record 33 of Set 8 | College
# Processing Record 34 of Set 8 | Vao
# Processing Record 35 of Set 8 | Archidona
# Processing Record 36 of Set 8 | Losheim
# Processing Record 37 of Set 8 | Vardo
# Processing Record 38 of Set 8 | Williston
# Processing Record 39 of Set 8 | Tobermory
# Processing Record 40 of Set 8 | Mackenzie
# Processing Record 41 of Set 8 | Castelbuono
# Processing Record 42 of Set 8 | Lompoc
# Processing Record 43 of Set 8 | Igrim
# Processing Record 44 of Set 8 | Kloulklubed
# Processing Record 45 of Set 8 | Naze
# Processing Record 46 of Set 8 | Tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 8 | Erzin
# Processing Record 48 of Set 8 | Bichena
# Processing Record 49 of Set 8 | Mangrol
# Processing Record 50 of Set 8 | Bayevo
# Processing Record 1 of Set 9 | Nishihara
# Processing Record 2 of Set 9 | Parli
# Processing Record 3 of Set 9 | Kendari
# Processing Record 4 of Set 9 | Isangel
# Processing Record 5 of Set 9 | Yarmouth
# Processing Record 6 of Set 9 | Wilmington
# Processing Record 7 of Set 9 | Kawana Waters
# City not found. Skipping...
# Processing Record 8 of Set 9 | Labuan
# Processing Record 9 of Set 9 | Shalya
# Processing Record 10 of Set 9 | Flinders
# Processing Record 11 of Set 9 | Manali
# Processing Record 12 of Set 9 | Namestovo
# Processing Record 13 of Set 9 | Kangaatsiaq
# Processing Record 14 of Set 9 | Commerce
# Processing Record 15 of Set 9 | Wyndham
# Processing Record 16 of Set 9 | Putina
# Processing Record 17 of Set 9 | Bowmore
# Processing Record 18 of Set 9 | Polunochnoye
# Processing Record 19 of Set 9 | Fortuna
# Processing Record 20 of Set 9 | Necochea
# Processing Record 21 of Set 9 | Tarancon
# Processing Record 22 of Set 9 | Lopukhiv
# Processing Record 23 of Set 9 | Nome
# Processing Record 24 of Set 9 | Izumo
# Processing Record 25 of Set 9 | Tulun
# Processing Record 26 of Set 9 | Hamilton
# Processing Record 27 of Set 9 | Tombouctou
# Processing Record 28 of Set 9 | Magan
# Processing Record 29 of Set 9 | Noumea
# Processing Record 30 of Set 9 | Rumonge
# Processing Record 31 of Set 9 | Kirovskiy
# Processing Record 32 of Set 9 | Rauma
# Processing Record 33 of Set 9 | Turukhansk
# Processing Record 34 of Set 9 | Golden Gate
# Processing Record 35 of Set 9 | Nambucca Heads
# Processing Record 36 of Set 9 | Zhanatas
# City not found. Skipping...
# Processing Record 37 of Set 9 | Vrangel
# Processing Record 38 of Set 9 | Ust-Kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 9 | Hokitika
# Processing Record 40 of Set 9 | Roebourne
# Processing Record 41 of Set 9 | Puerto Madero
# Processing Record 42 of Set 9 | Inuvik
# Processing Record 43 of Set 9 | Ouadda
# Processing Record 44 of Set 9 | Yulara
# Processing Record 45 of Set 9 | Tsotilion
# Processing Record 46 of Set 9 | Ewa Beach
# Processing Record 47 of Set 9 | Pokhara
# Processing Record 48 of Set 9 | Muros
# Processing Record 49 of Set 9 | Coahuayana
# Processing Record 50 of Set 9 | Kaduqli
# Processing Record 1 of Set 10 | Ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 10 | Riyadh
# Processing Record 3 of Set 10 | Banagher
# Processing Record 4 of Set 10 | Awbari
# Processing Record 5 of Set 10 | Lyubeshiv
# City not found. Skipping...
# Processing Record 6 of Set 10 | Viedma
# Processing Record 7 of Set 10 | Souillac
# Processing Record 8 of Set 10 | Farcasu
# Processing Record 9 of Set 10 | Huainan
# Processing Record 10 of Set 10 | Yirol
# City not found. Skipping...
# Processing Record 11 of Set 10 | Itoman
# Processing Record 12 of Set 10 | Angoche
# Processing Record 13 of Set 10 | Mehamn
# Processing Record 14 of Set 10 | Camacha
# Processing Record 15 of Set 10 | Viransehir
# Processing Record 16 of Set 10 | Aksarayskiy
# Processing Record 17 of Set 10 | Horsham
# Processing Record 18 of Set 10 | Palasa
# Processing Record 19 of Set 10 | Naspur
# Processing Record 20 of Set 10 | Edd
# Processing Record 21 of Set 10 | Tessalit
# Processing Record 22 of Set 10 | Piterka
# Processing Record 23 of Set 10 | Coro
# Processing Record 24 of Set 10 | Kruisfontein
# Processing Record 25 of Set 10 | Halalo
# City not found. Skipping...
# Processing Record 26 of Set 10 | Hualmay
# Processing Record 27 of Set 10 | Nantucket
# Processing Record 28 of Set 10 | Juneau
# Processing Record 29 of Set 10 | Rungata
# City not found. Skipping...
# Processing Record 30 of Set 10 | Yashan
# Processing Record 31 of Set 10 | Anchorage
# Processing Record 32 of Set 10 | Shangrao
# Processing Record 33 of Set 10 | Umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 10 | Gresham
# Processing Record 35 of Set 10 | Olinda
# Processing Record 36 of Set 10 | Xinyu
# Processing Record 37 of Set 10 | Livingstone
# Processing Record 38 of Set 10 | Batagay-Alyta
# Processing Record 39 of Set 10 | Bandarbeyla
# Processing Record 40 of Set 10 | Ampanihy
# Processing Record 41 of Set 10 | Berlevag
# Processing Record 42 of Set 10 | Rincon
# Processing Record 43 of Set 10 | Opuwo
# Processing Record 44 of Set 10 | Coxim
# Processing Record 45 of Set 10 | Boras
# Processing Record 46 of Set 10 | Emerald
# Processing Record 47 of Set 10 | Billings
# Processing Record 48 of Set 10 | Ahipara
# Processing Record 49 of Set 10 | Pontecagnano
# Processing Record 50 of Set 10 | Samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 11 | Gavle
# Processing Record 2 of Set 11 | Cherskiy
# Processing Record 3 of Set 11 | Aba
# Processing Record 4 of Set 11 | Nakhon Phanom
# Processing Record 5 of Set 11 | Semey
# Processing Record 6 of Set 11 | Sorland
# Processing Record 7 of Set 11 | Progreso
# Processing Record 8 of Set 11 | Mitsamiouli
# Processing Record 9 of Set 11 | Petropavlovsk-Kamchatskiy
# Processing Record 10 of Set 11 | Sitka
# Processing Record 11 of Set 11 | Saint-Pierre
# Processing Record 12 of Set 11 | Dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 11 | Burla
# Processing Record 14 of Set 11 | Aykhal
# Processing Record 15 of Set 11 | Muborak
# Processing Record 16 of Set 11 | Mtimbira
# Processing Record 17 of Set 11 | La Ronge
# Processing Record 18 of Set 11 | Shar
# Processing Record 19 of Set 11 | Hailar
# Processing Record 20 of Set 11 | Talnakh
# Processing Record 21 of Set 11 | Vaitape
# Processing Record 22 of Set 11 | Eyl
# Processing Record 23 of Set 11 | Tornio
# Processing Record 24 of Set 11 | Alcala
# Processing Record 25 of Set 11 | Preili
# Processing Record 26 of Set 11 | Anadyr
# Processing Record 27 of Set 11 | Faanui
# Processing Record 28 of Set 11 | Jam Sahib
# Processing Record 29 of Set 11 | Parainen
# Processing Record 30 of Set 11 | Kongolo
# Processing Record 31 of Set 11 | Santa Comba
# Processing Record 32 of Set 11 | Irbit
# Processing Record 33 of Set 11 | Tuatapere
# Processing Record 34 of Set 11 | Umm Lajj
# Processing Record 35 of Set 11 | Severo-Kurilsk
# Processing Record 36 of Set 11 | Sola
# Processing Record 37 of Set 11 | Moree
# Processing Record 38 of Set 11 | Nouadhibou
# Processing Record 39 of Set 11 | Sai Buri
# Processing Record 40 of Set 11 | Portland
# Processing Record 41 of Set 11 | Mount Gambier
# Processing Record 42 of Set 11 | Ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 11 | Luang Prabang
# Processing Record 44 of Set 11 | Alghero
# Processing Record 45 of Set 11 | Nemuro
# Processing Record 46 of Set 11 | Rodeo
# Processing Record 47 of Set 11 | Kuche
# City not found. Skipping...
# Processing Record 48 of Set 11 | Kikwit
# Processing Record 49 of Set 11 | Wanganui
# Processing Record 50 of Set 11 | Avera
# Processing Record 1 of Set 12 | Hofn
# Processing Record 2 of Set 12 | Umarkot
# Processing Record 3 of Set 12 | Stromness
# Processing Record 4 of Set 12 | Nahariyya
# Processing Record 5 of Set 12 | Tautira
# Processing Record 6 of Set 12 | Taonan
# Processing Record 7 of Set 12 | Duncan
# Processing Record 8 of Set 12 | Metehara
# City not found. Skipping...
# Processing Record 9 of Set 12 | Nizhneangarsk
# Processing Record 10 of Set 12 | Bikaner
# Processing Record 11 of Set 12 | Evensk
# Processing Record 12 of Set 12 | Padang
# Processing Record 13 of Set 12 | San Francisco
# Processing Record 14 of Set 12 | Sangueya
# Processing Record 15 of Set 12 | Abay
# Processing Record 16 of Set 12 | Huaicheng
# Processing Record 17 of Set 12 | Tubruq
# City not found. Skipping...
# Processing Record 18 of Set 12 | Yumen
# Processing Record 19 of Set 12 | Beberibe
# Processing Record 20 of Set 12 | Mezhdurechensk
# Processing Record 21 of Set 12 | Lakes Entrance
# Processing Record 22 of Set 12 | Tabou
# Processing Record 23 of Set 12 | Pastavy
# Processing Record 24 of Set 12 | Sainte-Anne-Des-Monts
# Processing Record 25 of Set 12 | Faya
# Processing Record 26 of Set 12 | Gigmoto
# Processing Record 27 of Set 12 | Mareeba
# Processing Record 28 of Set 12 | San Juan De Los Morros
# Processing Record 29 of Set 12 | Labuhan
# Processing Record 30 of Set 12 | Kattivakkam
# Processing Record 31 of Set 12 | San Policarpo
# Processing Record 32 of Set 12 | Palu
# Processing Record 33 of Set 12 | Ulagan
# Processing Record 34 of Set 12 | Bekhtery
# Processing Record 35 of Set 12 | Baghdad
# Processing Record 36 of Set 12 | Mae Hong Son
# Processing Record 37 of Set 12 | Cururupu
# Processing Record 38 of Set 12 | Gumrak
# Processing Record 39 of Set 12 | Sibolga
# Processing Record 40 of Set 12 | Fort Frances
# Processing Record 41 of Set 12 | Pontes E Lacerda
# Processing Record 42 of Set 12 | Changji
# Processing Record 43 of Set 12 | Boyabat
# Processing Record 44 of Set 12 | Moses Lake
# Processing Record 45 of Set 12 | Wanaka
# Processing Record 46 of Set 12 | Rosendal
# Processing Record 47 of Set 12 | Cabra
# Processing Record 48 of Set 12 | Puerto Narino
# Processing Record 49 of Set 12 | Yazd
# Processing Record 50 of Set 12 | Port Keats
# Processing Record 1 of Set 13 | Aljezur
# Processing Record 2 of Set 13 | Mosquera
# Processing Record 3 of Set 13 | Traverse City
# Processing Record 4 of Set 13 | Poum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather = {"City":cities, "City Latitude": city_lat, 
           "City Longitude": city_lon, "Temperature (F)": temp, 
           "Max Temperature (F)": max_temp, "Humidity (%)": humidity,
           "Cloud Coverage (%)": clouds, "Wind Speed (mph)": wind_speed, 
           "City Country": country, "City Datetime": city_date}

# %%
weather_df = pd.DataFrame.from_dict(weather, orient='index')
weather_df.transpose().head()
# Out:
#            City City Latitude City Longitude Temperature (F)  \
# 0      takayama       36.1333         137.25           49.91
# 1         bluff         -46.6       168.3333           47.35
# 2  puerto ayora       -0.7393       -90.3518           70.02
# 3        dikson       73.5069        80.5464           26.51
# 4  ponta do sol       32.6667          -17.1           81.99
#
#   Max Temperature (F) Humidity (%) Cloud Coverage (%) Wind Speed (mph)  \
# 0               51.03           98                100                3
# 1               47.35           59                 57            11.48
# 2               70.02           87                 99             7.92
# 3               26.51           61                100            16.22
# 4               86.72           68                100             1.01
#
#   City Country City Datetime
# 0           JP    1634649452
# 1           NZ    1634649601
# 2           EC    1634649602
# 3           RU    1634649603
# 4           PT    1634649604

# %%
cities_reports = weather_df.transpose().to_csv("cities_reports.csv", encoding="utf-8")
cities_reports

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
import csv
cities_weather = "../starter_code/cities_reports.csv"
cities_weather_df = pd.read_csv(cities_weather)
cities_weather_df
# Out:
#      Unnamed: 0           City  City Latitude  City Longitude  \
# 0             0       takayama        36.1333        137.2500
# 1             1          bluff       -46.6000        168.3333
# 2             2   puerto ayora        -0.7393        -90.3518
# 3             3         dikson        73.5069         80.5464
# 4             4   ponta do sol        32.6667        -17.1000
# ..          ...            ...            ...             ...
# 599         599     port keats            NaN             NaN
# 600         600        aljezur            NaN             NaN
# 601         601       mosquera            NaN             NaN
# 602         602  traverse city            NaN             NaN
# 603         603           poum            NaN             NaN
#
#      Temperature (F)  Max Temperature (F)  Humidity (%)  Cloud Coverage (%)  \
# 0              49.91                51.03          98.0               100.0
# 1              47.35                47.35          59.0                57.0
# 2              70.02                70.02          87.0                99.0
# 3              26.51                26.51          61.0               100.0
# 4              81.99                86.72          68.0               100.0
# ..               ...                  ...           ...                 ...
# 599              NaN                  NaN           NaN                 NaN
# 600              NaN                  NaN           NaN                 NaN
# 601              NaN                  NaN           NaN                 NaN
# 602              NaN                  NaN           NaN                 NaN
# 603              NaN                  NaN           NaN                 NaN
#
#      Wind Speed (mph) City Country  City Datetime
# 0                3.00           JP   1.634649e+09
# 1               11.48           NZ   1.634650e+09
# 2                7.92           EC   1.634650e+09
# 3               16.22           RU   1.634650e+09
# 4                1.01           PT   1.634650e+09
# ..                ...          ...            ...
# 599               NaN          NaN            NaN
# 600               NaN          NaN            NaN
# 601               NaN          NaN            NaN
# 602               NaN          NaN            NaN
# 603               NaN          NaN            NaN
#
# [604 rows x 11 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
city_data = cities_weather_df.dropna()
city_data = city_data.drop(city_data.columns[0], axis = 1)
city_data
# Out:
#               City  City Latitude  City Longitude  Temperature (F)  \
# 0         takayama        36.1333        137.2500            49.91
# 1            bluff       -46.6000        168.3333            47.35
# 2     puerto ayora        -0.7393        -90.3518            70.02
# 3           dikson        73.5069         80.5464            26.51
# 4     ponta do sol        32.6667        -17.1000            81.99
# ..             ...            ...             ...              ...
# 538       sai buri       -14.2500        129.5500            82.11
# 539       portland        37.3191         -8.8033            80.92
# 540  mount gambier         4.7059        -74.2302            57.29
# 541  ambodifototra        44.7631        -85.6206            50.61
# 542  luang prabang       -20.2333        164.0167            75.78
#
#      Max Temperature (F)  Humidity (%)  Cloud Coverage (%)  Wind Speed (mph)  \
# 0                  51.03          98.0               100.0              3.00
# 1                  47.35          59.0                57.0             11.48
# 2                  70.02          87.0                99.0              7.92
# 3                  26.51          61.0               100.0             16.22
# 4                  86.72          68.0               100.0              1.01
# ..                   ...           ...                 ...               ...
# 538                82.11          79.0                97.0              7.47
# 539                80.92          41.0                90.0              7.65
# 540                57.29          77.0                20.0              4.61
# 541                54.61          93.0                 1.0              0.00
# 542                75.78          84.0               100.0              8.88
#
#     City Country  City Datetime
# 0             JP   1.634649e+09
# 1             NZ   1.634650e+09
# 2             EC   1.634650e+09
# 3             RU   1.634650e+09
# 4             PT   1.634650e+09
# ..           ...            ...
# 538           AU   1.634650e+09
# 539           PT   1.634650e+09
# 540           CO   1.634650e+09
# 541           US   1.634650e+09
# 542           NC   1.634650e+09
#
# [539 rows x 10 columns]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
indices = city_data[city_data['Humidity (%)']>100].index
clean_city_data = city_data.drop(indices, inplace=False)
clean_city_data
# Out:
#               City  City Latitude  City Longitude  Temperature (F)  \
# 0         takayama        36.1333        137.2500            49.91
# 1            bluff       -46.6000        168.3333            47.35
# 2     puerto ayora        -0.7393        -90.3518            70.02
# 3           dikson        73.5069         80.5464            26.51
# 4     ponta do sol        32.6667        -17.1000            81.99
# ..             ...            ...             ...              ...
# 538       sai buri       -14.2500        129.5500            82.11
# 539       portland        37.3191         -8.8033            80.92
# 540  mount gambier         4.7059        -74.2302            57.29
# 541  ambodifototra        44.7631        -85.6206            50.61
# 542  luang prabang       -20.2333        164.0167            75.78
#
#      Max Temperature (F)  Humidity (%)  Cloud Coverage (%)  Wind Speed (mph)  \
# 0                  51.03          98.0               100.0              3.00
# 1                  47.35          59.0                57.0             11.48
# 2                  70.02          87.0                99.0              7.92
# 3                  26.51          61.0               100.0             16.22
# 4                  86.72          68.0               100.0              1.01
# ..                   ...           ...                 ...               ...
# 538                82.11          79.0                97.0              7.47
# 539                80.92          41.0                90.0              7.65
# 540                57.29          77.0                20.0              4.61
# 541                54.61          93.0                 1.0              0.00
# 542                75.78          84.0               100.0              8.88
#
#     City Country  City Datetime
# 0             JP   1.634649e+09
# 1             NZ   1.634650e+09
# 2             EC   1.634650e+09
# 3             RU   1.634650e+09
# 4             PT   1.634650e+09
# ..           ...            ...
# 538           AU   1.634650e+09
# 539           PT   1.634650e+09
# 540           CO   1.634650e+09
# 541           US   1.634650e+09
# 542           NC   1.634650e+09
#
# [539 rows x 10 columns]

# %%
city_data_reports = clean_city_data.to_csv("city_data_reports.csv", encoding="utf-8")
city_data_reports

# %%
perc = [.25, .50, .75]
include = ['object', 'float', 'int']

describe_city = clean_city_data.drop(columns=['City','Temperature (F)', 'City Country'], axis = 1).describe(percentiles=perc, include=include)
describe_city
# Out:
#        City Latitude  City Longitude  Max Temperature (F)  Humidity (%)  \
# count     539.000000      539.000000           539.000000    539.000000
# mean       22.316433       21.959585            61.392560     69.740260
# std        33.196892       91.939409            21.294194     22.505168
# min       -54.800000     -179.166700           -14.690000      7.000000
# 25%        -3.872700      -55.690350            46.760000     57.500000
# 50%        28.233300       26.891000            65.100000     75.000000
# 75%        49.552650      101.667250            78.890000     87.000000
# max        78.218600      179.316700            99.250000    100.000000
#
#        Cloud Coverage (%)  Wind Speed (mph)  City Datetime
# count          539.000000        539.000000   5.390000e+02
# mean            59.064935          8.183414   1.634650e+09
# std             40.287414          5.961137   1.729286e+02
# min              0.000000          0.000000   1.634649e+09
# 25%             14.000000          3.510000   1.634650e+09
# 50%             75.000000          7.000000   1.634650e+09
# 75%            100.000000         11.465000   1.634650e+09
# max            100.000000         42.370000   1.634650e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_data["City Latitude"], city_data["Max Temperature (F)"], edgecolor="black", linewidth = .75)
plt.title("City Latitude vs Max Temperature)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid()
#plt.savefig("LatvsTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_data["City Latitude"], city_data["Humidity (%)"], edgecolor="black", linewidth = .75)
plt.title("City Latitude vs Humidity (%) ")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
#plt.savefig("LatvsHum.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data["City Latitude"], city_data["Cloud Coverage (%)"], edgecolor="black", linewidth = .75)
plt.title("City Latitude vs Cloudiness (%) ")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
#plt.savefig("LatvsCloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data["City Latitude"], city_data["Wind Speed (mph)"], edgecolor="black", linewidth = .75)
plt.title("City Latitude vs Wind Speed (mph) ")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
#plt.savefig("LatvsWind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
n_hemp = clean_city_data.loc[clean_city_data["City Latitude"]>0]
n_hemp.head()
# Out:
#                      City  City Latitude  City Longitude  Temperature (F)  \
# 0                takayama        36.1333        137.2500            49.91
# 3                  dikson        73.5069         80.5464            26.51
# 4            ponta do sol        32.6667        -17.1000            81.99
# 5   tenango de rio blanco        34.2001        -90.5709            49.30
# 10                ushuaia        61.9940        -49.6678            37.98
#
#     Max Temperature (F)  Humidity (%)  Cloud Coverage (%)  Wind Speed (mph)  \
# 0                 51.03          98.0               100.0              3.00
# 3                 26.51          61.0               100.0             16.22
# 4                 86.72          68.0               100.0              1.01
# 5                 52.92         100.0                 1.0              5.41
# 10                37.98          59.0                 0.0              4.23
#
#    City Country  City Datetime
# 0            JP   1.634649e+09
# 3            RU   1.634650e+09
# 4            PT   1.634650e+09
# 5            US   1.634650e+09
# 10           GL   1.634650e+09

# %%
s_hemp = clean_city_data.loc[clean_city_data["City Latitude"]<0]
s_hemp.head()
# Out:
#            City  City Latitude  City Longitude  Temperature (F)  \
# 1         bluff       -46.6000        168.3333            47.35
# 2  puerto ayora        -0.7393        -90.3518            70.02
# 6    clarksdale       -42.8794        147.3294            41.31
# 7        hobart        -9.8000       -139.0333            76.98
# 8        atuona       -21.2000       -175.2000            71.76
#
#    Max Temperature (F)  Humidity (%)  Cloud Coverage (%)  Wind Speed (mph)  \
# 1                47.35          59.0                57.0             11.48
# 2                70.02          87.0                99.0              7.92
# 6                43.05          78.0                86.0              1.01
# 7                76.98          79.0                55.0             21.63
# 8                71.76          88.0                20.0              8.05
#
#   City Country  City Datetime
# 1           NZ   1.634650e+09
# 2           EC   1.634650e+09
# 6           AU   1.634649e+09
# 7           PF   1.634650e+09
# 8           TO   1.634650e+09

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
n_lat = n_hemp["City Latitude"]
n_max_temp = n_hemp["Max Temperature (F)"]
plt.scatter(n_lat, n_max_temp)
plt.xlabel("Latitude")
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temperature (F)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_max_temp)
regress_values = n_lat * slope + intercept
line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.plot(n_lat, regress_values,"r-")
plt.grid()
#plt.savefig("north_max_tempvslat.png")
plt.show()
print(f"Linear Equation is : {line_eq}")
print(f"The r-value is: {rvalue}")
print(f"The p-value is: {pvalue}")
# Out:
# Linear Equation is : y = -0.99 x + 97.28
# The r-value is: -0.8338376981636574
# The p-value is: 7.736648639374778e-100

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_lat = s_hemp["City Latitude"]
s_max_temp = s_hemp["Max Temperature (F)"]
plt.scatter(s_lat, s_max_temp)
plt.xlabel("Latitude")
plt.title("Southern Hemisphere - Max Temp vs. Latitude (10/30/20)")
plt.ylabel("Max Temperature (F)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_max_temp)
regress_values = s_lat * slope + intercept
line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.plot(s_lat, regress_values,"r-")
plt.grid()
#plt.savefig("south_max_tempvslat.png")
plt.show()
print(f"Linear Equation is : {line_eq}")
print(f"The r-value is: {rvalue}")
print(f"The p-value is: {pvalue}")
# Out:
# Linear Equation is : y = 0.67 x + 84.75
# The r-value is: 0.7455961316001026
# The p-value is: 2.706902576368052e-29

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_lat = n_hemp["City Latitude"]
n_humidity = n_hemp["Humidity (%)"]
plt.scatter(n_lat, n_humidity)
plt.xlabel("Latitude")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude (10/30/20)")
plt.ylabel("Humidity (%)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_humidity)
regress_values = n_lat * slope + intercept
line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.plot(n_lat, regress_values,"r-")
plt.grid()
#plt.savefig("north_humidvslat.png")
plt.show()
print(f"Linear Equation is : {line_eq}")
print(f"The r-value is: {rvalue}")
print(f"The p-value is: {pvalue}")
# Out:
# Linear Equation is : y = 0.23 x + 59.73
# The r-value is: 0.18728080243047757
# The p-value is: 0.000236788202836094

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_lat = s_hemp["City Latitude"]
s_humidity = s_hemp["Humidity (%)"]
plt.scatter(s_lat, s_humidity)
plt.xlabel("Latitude")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude (10/30/20)")
plt.ylabel("Humidity (%)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_humidity)
regress_values = s_lat * slope + intercept
line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.plot(s_lat, regress_values,"r-")
plt.grid()
#plt.savefig("south_humidvslat.png")
plt.show()
print(f"Linear Equation is : {line_eq}")
print(f"The r-value is: {rvalue}")
print(f"The p-value is: {pvalue}")
# Out:
# Linear Equation is : y = 0.26 x + 76.94
# The r-value is: 0.19456689574812563
# The p-value is: 0.014297270753171366

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_lat = n_hemp["City Latitude"]
n_cloud = n_hemp["Cloud Coverage (%)"]
plt.scatter(n_lat, n_cloud)
plt.xlabel("Latitude")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude (10/30/20)")
plt.ylabel("Cloudiness (%)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_cloud)
regress_values = n_lat * slope + intercept
line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.plot(n_lat, regress_values,"r-")
plt.grid()
#plt.savefig("north_cloudvslat.png")
plt.show()
print(f"Linear Equation is : {line_eq}")
print(f"The r-value is: {rvalue}")
print(f"The p-value is: {pvalue}")
# Out:
# Linear Equation is : y = 0.34 x + 44.65
# The r-value is: 0.16171386199155158
# The p-value is: 0.0015400590192376157

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_lat = s_hemp["City Latitude"]
s_cloud = s_hemp["Cloud Coverage (%)"]
plt.scatter(s_lat, s_cloud)
plt.xlabel("Latitude")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude (10/30/20)")
plt.ylabel("Cloudiness (%)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_cloud)
regress_values = s_lat * slope + intercept
line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.plot(s_lat, regress_values,"r-")
plt.grid()
plt.savefig("south_cloudvslat.png")
plt.show()
print(f"Linear Equation is : {line_eq}")
print(f"The r-value is: {rvalue}")
print(f"The p-value is: {pvalue}")
# Out:
# Linear Equation is : y = 1.07 x + 82.97
# The r-value is: 0.38680402019150006
# The p-value is: 5.160370665156772e-07

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_lat = n_hemp["City Latitude"]
n_wind = n_hemp["Wind Speed (mph)"]
plt.scatter(n_lat, n_wind)
plt.xlabel("Latitude")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude (10/30/20)")
plt.ylabel("Wind Speed (mph)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_wind)
regress_values = n_lat * slope + intercept
line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.plot(n_lat, regress_values,"r-")
plt.grid()
#plt.savefig("north_windvslat.png")
plt.show()
print(f"Linear Equation is : {line_eq}")
print(f"The r-value is: {rvalue}")
print(f"The p-value is: {pvalue}")
# Out:
# Linear Equation is : y = 0.05 x + 6.05
# The r-value is: 0.16157811963461366
# The p-value is: 0.0015543866419867923

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_lat = s_hemp["City Latitude"]
s_wind = s_hemp["Wind Speed (mph)"]
plt.scatter(s_lat, s_wind)
plt.xlabel("Latitude")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude (10/30/20)")
plt.ylabel("Wind Speed (mph)")

(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_wind)
regress_values = s_lat * slope + intercept
line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.plot(s_lat, regress_values,"r-")
plt.grid()
#plt.savefig("south_windvslat.png")
plt.show()
print(f"Linear Equation is : {line_eq}")
print(f"The r-value is: {rvalue}")
print(f"The p-value is: {pvalue}")
# Out:
# Linear Equation is : y = -0.09 x + 6.6
# The r-value is: -0.2107040955714036
# The p-value is: 0.007875040232079236
